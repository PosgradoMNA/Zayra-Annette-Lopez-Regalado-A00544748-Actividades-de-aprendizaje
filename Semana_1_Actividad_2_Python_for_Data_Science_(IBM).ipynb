# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/Zayra-Annette-Lopez-Regalado-A00544748-Actividades-de-aprendizaje/blob/main/Semana_1_Actividad_2_Python_for_Data_Science_(IBM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Module 1**

# %%
print("Hello\nWorld!")
# Out:
# Hello
# World!

# %%
# print('Hello World!')

# %%
"0123456".find('1')
# Out:
# 1

# %%
3+2*2
# Out:
# 7

# %%
name = 'Lizz'
print(name[0:2])
# Out:
# Li

# %%
var = '01234567'
print(var[::2])
# Out:
# 0246

# %%
'1'+'2'
# Out:
# '12'

# %%
myvar = 'hello'

# %% [markdown]
# ![Course Progress for 'ZayraLopez' Module1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# # **Module 2**

# %%
A=(0,1,2,3)
A[3]
# Out:
# 3

# %%
B=["a","b","c"]
B[1:]
# Out:
# ['b', 'c']

# %%
S={'A','B','C'}
U={'A','Z','C'}
U.union(S)
# Out:
# {'A', 'B', 'C', 'Z'}

# %%
S={'A','B','C'}
U={'A','Z','C'}

# %%
D = {'a':0,'b':1,'c':2}
D.values()
# Out:
# dict_values([0, 1, 2])

# %%
D = {'a':0,'b':1,'c':2}
D['b']
# Out:
# 1

# %%
A = ('a','b','c')
A[0]
# Out:
# 'a'

# %%
Dict={"A":1,"B":"2","C":[3,3,3],"D":(4,4,4),'E':5,'F':6}
Dict["D"]
# Out:
# (4, 4, 4)

# %% [markdown]
# # **Module 3**

# %%
x='a'
if(x!='a'):
  print("This is not a.")
else:
  print("This is a.")
# Out:
# This is a.

# %%
A=[3,4,5]
for a in A:
  print(a)
# Out:
# 3
# 4
# 5

# %%
x=3
y=1
while(y!=x):
  print(y)
  y=y+1
# Out:
# 1
# 2

# %%
a=1
def add(b):
  return a+b
  c=add(10)
def f(*x):
  return sum(x)

# %%
make="Honda"
model="Accord"
color="blue"

# %%
x=1
if(x!=1):
  print('Hello')
else:
  print('Hi')
print('Mike')
# Out:
# Hi
# Mike

# %%
A = ['1','2','3']
for a in A:
  print(2*a)
# Out:
# 11
# 22
# 33

# %%
def Delta(x):
  if x==0:
    y=1;
  else:
    y=0;
  return(y)

# %% [markdown]
# ![Avance modulo 3.PNG](data:image/png;base64,...)

# %% [markdown]
# # **Module 4**

# %%
df=pd.DataFrame({'a':[1,2,1],'b':[1,1,1]})
df['a']==1
# Out:
# 0     True
# 1    False
# 2     True
# Name: a, dtype: bool

# %% [markdown]
# ![Avance modulo 4.PNG](data:image/png;base64,...)
